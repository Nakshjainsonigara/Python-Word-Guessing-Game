# %%
import random
Level1=[
        'Lion', 'Tiger', 'Elephant', 'Giraffe', 'Zebra', 'Cheetah', 'Kangaroo', 'Gorilla',
        'Penguin', 'Dolphin', 'Whale', 'Polar Bear', 'Panda', 'Koala', 'Chimpanzee', 'Rhinoceros',
        'Octopus', 'Crocodile', 'Hippopotamus', 'Owl', 'Eagle', 'Parrot', 'Toucan', 'Sloth',
        'Komodo Dragon', 'Alligator', 'Bison', 'Seahorse', 'Flamingo', 'Peacock', 'Platypus',
        'Armadillo', 'Red Fox', 'Snow Leopard', 'Sea Turtle', 'Raccoon', 'Meerkat', 'Red Panda',
        'Praying Mantis', 'Tarantula'
    ]
Level2= [
    'Sparrow', 'Hawk', 'Pigeon', 'Robin', 'Eagle', 'Finch', 'Owl', 'Woodpecker', 'Pelican',
    'Seagull', 'Hummingbird', 'Crow', 'Parrot', 'Heron', 'Blue Jay', 'Toucan', 'Flamingo', 
    'Canary', 'Kingfisher', 'Swan'
]
Level3 =[
    'Great White Shark', 'Dolphin', 'Blue Whale', 'Orca', 'Humpback Whale', 'Narwhal', 
    'Manatee', 'Sea Lion', 'Walrus', 'Sea Otter', 'Green Sea Turtle', 'Loggerhead Turtle', 'Pufferfish', 
    'Seahorse', 'Lobster', 'Starfish', 'Coral Reef', 'Clownfish', 'Sea Anemone', 'Jellyfish', 
    'Octopus', 'Squid', 'Cuttlefish', 'Sea Slug', 'Dugong', 'Manta Ray', 'Stingray', 'Moray Eel', 
    'Barracuda', 'Angelfish', 'Giant Clam', 'Giant Squid', 'Sea Cucumber', 'Box Jellyfish', 
    'Electric Eel', 'Plankton', 'Swordfish', 'Hammerhead Shark', 'Tuna'
]
print("Welcome to the Word Guessing Game!")
print("You will be presented with words to guess.")
print("You have 3 chances for each word.")
print("If you guess a word correctly, you'll move to the next level.")
print("Complete all three levels to win the game.")
word=random.choice(Level1).lower()
a =1
while a<=3:
    print(word)
    g = input("Guess The word : ") 
    if g==word:
        word=random.choice(Level1).lower()
        print(word)
        K = input("Guess The second word :")
        if word==K:
            print("HURRAH!! you are promoted to level 2")
            a =1
            while a<=3:
                print(word)
                m = input("Guess The word : ") 
                if m==word:
                    word=random.choice(Level2).lower()
                    print(word)
                    K = input("Guess The second word :")
                    if word==K:
                        print("HURRAH!! you are promoted to level 3")
                        a=1
                        word=random.choice(Level3).lower()
                        while a<=3:
                            print(word)
                            m = input("Guess The word : ") 
                            if m==word:
                                word=random.choice(Level3).lower()
                                print(word)
                                K = input("Guess The second word :")
                                if word==K:
                                    print("HURRAH!! YOU WON")
                                    a=5
                                    break
                                else:
                                    print("try again")
                                    print("you have",3-a,"chances")
                                    a +=1
                            else:
                                print("try again")
                                print("you have",3-a,"chances")
                                a +=1
                else:
                    print("try again")
                    print("you have",3-a,"chances")
                    a +=1
        else:
            print("try again")
            print("you have",3-a,"chances")
            a +=1
    else :
        print("try again")
        print("you have",3-a,"chances")
        a +=1
    if a == 4: 
        print("SO SORRY!!😞You lose")
# Out:
# Welcome to the Word Guessing Game!
# You will be presented with words to guess.
# You have 3 chances for each word.
# If you guess a word correctly, you'll move to the next level.
# Complete all three levels to win the game.
# rhinoceros
# Guess The word : rhinoceros
# chimpanzee
# Guess The second word :chimpanzee
# HURRAH!! you are promoted to level 2
# chimpanzee
# Guess The word :
# try again
# you have 2 chances
# chimpanzee
# Guess The word :
# try again
# you have 1 chances
# chimpanzee
# Guess The word :
# try again
# you have 0 chances
# SO SORRY!!😞You lose
